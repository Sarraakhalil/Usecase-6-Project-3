# %%
# !pip install sweetviz
# Out:
# Requirement already satisfied: sweetviz in c:\users\gharb\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\gharb\anaconda3\lib\site-packages (from sweetviz) (2.2.2)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\gharb\anaconda3\lib\site-packages (from sweetviz) (1.26.4)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\gharb\anaconda3\lib\site-packages (from sweetviz) (3.8.4)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\gharb\anaconda3\lib\site-packages (from sweetviz) (4.66.4)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\gharb\anaconda3\lib\site-packages (from sweetviz) (1.13.1)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\gharb\anaconda3\lib\site-packages (from sweetviz) (3.1.4)
# Requirement already satisfied: importlib-resources>=1.2.0 in c:\users\gharb\anaconda3\lib\site-packages (from sweetviz) (6.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gharb\anaconda3\lib\site-packages (from jinja2>=2.11.1->sweetviz) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gharb\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gharb\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gharb\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gharb\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\gharb\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\gharb\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gharb\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gharb\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gharb\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gharb\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2023.3)
# Requirement already satisfied: colorama in c:\users\gharb\anaconda3\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\gharb\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)

# %%
import sys
# !{sys.executable} -m pip install -U ydata-profiling[notebook]
# !pip install jupyter-contrib-nbextensions
# Out:
# Requirement already satisfied: ydata-profiling[notebook] in c:\users\gharb\anaconda3\lib\site-packages (4.9.0)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (2.2.2)
# Requirement already satisfied: matplotlib<3.10,>=3.5 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (3.8.4)
# Requirement already satisfied: pydantic>=2 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (2.5.3)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (3.1.4)
# Requirement already satisfied: visions<0.7.7,>=0.7.5 in c:\users\gharb\anaconda3\lib\site-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling[notebook]) (0.7.6)
# Requirement already satisfied: numpy<2,>=1.16.0 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.26.4)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (2.32.2)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (4.66.4)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.14.2)
# Requirement already satisfied: typeguard<5,>=3 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (4.3.0)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.1 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.9.3)
# Requirement already satisfied: dacite>=1.8 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.8.1)
# Requirement already satisfied: numba<1,>=0.56.0 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.59.1)
# Requirement already satisfied: jupyter>=1.0.0 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.0.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\gharb\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (7.8.1)
# Requirement already satisfied: PyWavelets in c:\users\gharb\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling[notebook]) (1.5.0)
# Requirement already satisfied: pillow in c:\users\gharb\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling[notebook]) (10.3.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\gharb\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\gharb\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\gharb\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\gharb\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\gharb\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (8.25.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\gharb\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gharb\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling[notebook]) (2.1.3)
# Requirement already satisfied: notebook in c:\users\gharb\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (7.0.8)
# Requirement already satisfied: qtconsole in c:\users\gharb\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (5.5.1)
# Requirement already satisfied: jupyter-console in c:\users\gharb\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\gharb\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (7.10.0)
# Requirement already satisfied: ipykernel in c:\users\gharb\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (6.28.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gharb\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling[notebook]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gharb\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling[notebook]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gharb\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling[notebook]) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gharb\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling[notebook]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\gharb\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling[notebook]) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gharb\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling[notebook]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gharb\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling[notebook]) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\gharb\anaconda3\lib\site-packages (from numba<1,>=0.56.0->ydata-profiling[notebook]) (0.42.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gharb\anaconda3\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling[notebook]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gharb\anaconda3\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling[notebook]) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\gharb\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling[notebook]) (1.4.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\gharb\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling[notebook]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\gharb\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling[notebook]) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\gharb\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling[notebook]) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gharb\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gharb\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gharb\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gharb\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (2024.7.4)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\gharb\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling[notebook]) (0.5.6)
# Requirement already satisfied: colorama in c:\users\gharb\anaconda3\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling[notebook]) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\gharb\anaconda3\lib\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling[notebook]) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\gharb\anaconda3\lib\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling[notebook]) (3.2.1)
# Requirement already satisfied: decorator in c:\users\gharb\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\gharb\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\gharb\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\gharb\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\gharb\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\gharb\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.0)
# Requirement already satisfied: six in c:\users\gharb\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata-profiling[notebook]) (1.16.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\gharb\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\gharb\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in c:\users\gharb\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\gharb\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\gharb\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (6.4.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\gharb\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\gharb\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\gharb\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (5.7.2)
# Requirement already satisfied: nest-asyncio in c:\users\gharb\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (1.6.0)
# Requirement already satisfied: psutil in c:\users\gharb\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\gharb\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (25.1.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (1.2.1)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\gharb\anaconda3\lib\site-packages (from qtconsole->jupyter>=1.0.0->ydata-profiling[notebook]) (2.4.1)
# Requirement already satisfied: webencodings in c:\users\gharb\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\gharb\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (305.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\gharb\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\gharb\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\gharb\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\gharb\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\gharb\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (4.19.2)
# Requirement already satisfied: fastjsonschema in c:\users\gharb\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\gharb\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\gharb\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (2.5)
# Requirement already satisfied: executing in c:\users\gharb\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\gharb\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\gharb\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\gharb\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\gharb\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (21.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\gharb\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\gharb\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\gharb\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.0.7)
# Requirement already satisfied: rfc3339-validator in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\gharb\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\gharb\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\gharb\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.1)
# Requirement already satisfied: uri-template in c:\users\gharb\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\gharb\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (24.6.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\gharb\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\gharb\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\gharb\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.2.3)
# Requirement already satisfied: jupyter-contrib-nbextensions in c:\users\gharb\anaconda3\lib\site-packages (0.7.0)
# Requirement already satisfied: ipython-genutils in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (0.4.2)
# Requirement already satisfied: jupyter-core in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (5.7.2)
# Requirement already satisfied: jupyter-highlight-selected-word>=0.1.1 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-nbextensions-configurator>=0.4.0 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (0.6.4)
# Requirement already satisfied: nbconvert>=6.0 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (7.10.0)
# Requirement already satisfied: notebook>=6.0 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (7.0.8)
# Requirement already satisfied: tornado in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (6.4.1)
# Requirement already satisfied: traitlets>=4.1 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (5.14.3)
# Requirement already satisfied: lxml in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (5.2.1)
# Requirement already satisfied: setuptools in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-contrib-core>=0.3.3->jupyter-contrib-nbextensions) (69.5.1)
# Requirement already satisfied: jupyter-server in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.14.1)
# Requirement already satisfied: pyyaml in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (6.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (5.9.2)
# Requirement already satisfied: packaging in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (23.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (2.15.1)
# Requirement already satisfied: tinycss2 in c:\users\gharb\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (1.2.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-core->jupyter-contrib-nbextensions) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-core->jupyter-contrib-nbextensions) (305.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\gharb\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in c:\users\gharb\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\gharb\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (0.2.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\gharb\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.0->jupyter-contrib-nbextensions) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\gharb\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.0->jupyter-contrib-nbextensions) (0.5.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (8.6.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\gharb\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (2.0.4)
# Requirement already satisfied: ipykernel in c:\users\gharb\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\gharb\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\gharb\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\gharb\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\gharb\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (4.19.2)
# Requirement already satisfied: requests>=2.31 in c:\users\gharb\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.32.2)
# Requirement already satisfied: fastjsonschema in c:\users\gharb\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter-contrib-nbextensions) (2.16.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\gharb\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter-contrib-nbextensions) (2.5)
# Requirement already satisfied: idna>=2.8 in c:\users\gharb\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\gharb\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\gharb\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\gharb\anaconda3\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (2024.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\gharb\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\gharb\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\gharb\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\gharb\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.9.0.post0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.0.7)
# Requirement already satisfied: rfc3339-validator in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\gharb\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gharb\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gharb\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gharb\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (2024.7.4)
# Requirement already satisfied: comm>=0.1.1 in c:\users\gharb\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\gharb\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\gharb\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (8.25.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\gharb\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\gharb\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (1.6.0)
# Requirement already satisfied: psutil in c:\users\gharb\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (5.9.0)
# Requirement already satisfied: decorator in c:\users\gharb\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\gharb\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\gharb\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (3.0.43)
# Requirement already satisfied: stack-data in c:\users\gharb\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: colorama in c:\users\gharb\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (0.4.6)
# Requirement already satisfied: fqdn in c:\users\gharb\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\gharb\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\gharb\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.1)
# Requirement already satisfied: uri-template in c:\users\gharb\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\gharb\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (24.6.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\gharb\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\gharb\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\gharb\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\gharb\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.5)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\gharb\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.2.3)
# Requirement already satisfied: executing in c:\users\gharb\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\gharb\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\gharb\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.2)

# %%
#Import all relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
from ydata_profiling import ProfileReport
import sweetviz as sv

 
## This statement allows the visuals to render within your Jupyter Notebook.
# %matplotlib inline

# %% [markdown]
# ## Loading the data
# We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
df = pd.read_excel(r"C:\Users\gharb\OneDrive\Desktop\Datasets\Riyadh\Riyadh_Aqqar.xlsx")

# %% [markdown]
# ### Viewing the dataframe
# We can get a quick sense of the size of our dataset by using the shape method. This returns a tuple with the number of rows and columns in the dataset.

# %%
profile = ProfileReport(df, title="Pandas Profiling Report")
profile.to_notebook_iframe()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.9.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-08-10 13:01:24.445736&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
#  *//*! normalize.css v3.0.3 | MIT License | github.com/necolas/normalize.css */html{font-family:sans-serif;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%}body{margin:0}article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section,summary{display:block}audio,canvas,progress,video{display:inline-block;vertical-align:baseline}audio:not([controls]){display:none;height:0}[hidden],template{display:none}a{background-color:transparent}a:active,a:hover{outline:0}abbr[title]{border-bottom:1px dotted}b,strong{font-weight:700}dfn{font-style:italic}h1{margin:.67em 0;font-size:2em}mark{color:#000;background:#ff0}small{font-size:80%}sub,sup{position:relative;font-size:75%;line-height:0;vertical-align:baseline}sup{top:-.5em}sub{bottom:-.25em}img{border:0}svg:not(:root){overflow:hidden}figure{margin:1em 40px}hr{height:0;-webkit-box-sizing:content-box;-moz-box-sizing:content-box;box-sizing:content-box}pre{overflow:auto}code,kbd,pre,samp{font-family:monospace,monospace;font-size:1em}button,input,optgroup,select,textarea{margin:0;font:inherit;color:inherit}button{overflow:visible}button,select{text-transform:none}button,html input[type=button],input[type=reset],input[type=submit]{-webkit-appearance:button;cursor:pointer}button[disabled],html input[disabled]{cursor:default}button::-moz-focus-inner,input::-moz-focus-inner{padding:0;border:0}input{line-height:normal}input[type=checkbox],input[type=radio]{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box;padding:0}input[type=number]::-webkit-inner-spin-button,input[type=number]::-webkit-outer-spin-button{height:auto}input[type=search]{-webkit-box-sizing:content-box;-moz-box-sizing:content-box;box-sizing:content-box;-webkit-appearance:textfield}input[type=search]::-webkit-search-cancel-button,input[type=search]::-webkit-search-decoration{-webkit-appearance:none}fieldset{padding:.35em .625em .75em;margin:0 2px;border:1px solid silver}legend{padding:0;border:0}textarea{overflow:auto}optgroup{font-weight:700}table{border-spacing:0;border-collapse:collapse}td,th{padding:0}/*! Source: https://github.com/h5bp/html5-boilerplate/blob/master/src/css/main.css */@media print{*,:after,:before{color:#000!important;text-shadow:none!important;background:0 0!important;-webkit-box-shadow:none!important;box-shadow:none!important}a,a:visited{text-decoration:underline}a[href]:after{content:&quot; (&quot; attr(href) &quot;)&quot;}abbr[title]:after{content:&quot; (&quot; attr(title) &quot;)&quot;}a[href^=&quot;javascript:&quot;]:after,a[href^=&quot;#&quot;]:after{content:&quot;&quot;}blockquote,pre{border:1px solid #999;page-break-inside:avoid}thead{display:table-header-group}img,tr{page-break-inside:avoid}img{max-width:100%!important}h2,h3,p{orphans:3;widows:3}h2,h3{page-break-after:avoid}.navbar{display:none}.btn&gt;.caret,.dropup&gt;.btn&gt;.caret{border-top-color:#000!important}.label{border:1px solid #000}.table{border-collapse:collapse!important}.table td,.table th{background-color:#fff!important}.table-bordered td,.table-bordered th{border:1px solid #ddd!important}}@font-face{font-family:&#x27;Glyphicons Halflings&#x27;;src:url(../fonts/glyphicons-halflings-regular.eot);src:url(../fonts/glyphicons-halflings-regular.eot?#iefix) format(&#x27;embedded-opentype&#x27;),url(../fonts/glyphicons-halflings-regular.woff2) format(&#x27;woff2&#x27;),url(../fonts/glyphicons-halflings-regular.woff) format(&#x27;woff&#x27;),url(../fonts/glyphicons-halflings-regular.ttf) format(&#x27;truetype&#x27;),url(../fonts/glyphicons-halflings-regular.svg#glyphicons_halflingsregular) format(&#x27;svg&#x27;)}.glyphicon{position:relative;top:1px;display:inline-block;font-family:&#x27;Glyphicons Halflings&#x27;;font-style:normal;font-weight:400;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.glyphicon-asterisk:before{content:&quot;\002a&quot;}.glyphicon-plus:before{content:&quot;\002b&quot;}.glyphicon-eur:before,.glyphicon-euro:before{content:&quot;\20 ...

# %% [markdown]
# ## 1. Data Profiling:
# Data profiling is a comprehensive process of examining the data available in an existing dataset and collecting statistics and information about that data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1594 entries, 0 to 2154
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   نوع العقار      1594 non-null   object
#  1   الغرض           1594 non-null   object
#  2   المدينة         1591 non-null   object
#  3   الحي            1594 non-null   object
#  4   الواجهة         1594 non-null   object
#  5   المساحة         1594 non-null   int64
#  6   سعر المتر       1594 non-null   float64
#  7   السعر الإجمالي  1594 non-null   int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 112.1+ KB

# %%
df.describe()
# Out:
#            المساحة    سعر المتر  السعر الإجمالي
# count  1594.000000  1594.000000    1.594000e+03
# mean    641.670640  2603.231291    1.586830e+06
# std     325.617395  1680.721596    1.224362e+06
# min       1.000000   235.000000    1.400000e+03
# 25%     400.000000  1280.000000    6.763005e+05
# 50%     550.000000  2300.000000    1.193175e+06
# 75%     810.000000  3500.000000    2.192188e+06
# max    2000.000000  7500.000000    6.000000e+06

# %%
df.shape
# Out:
# (1594, 8)

# %%
df.columns
# Out:
# Index(['نوع العقار', 'الغرض', 'المدينة', 'الحي', 'الواجهة', 'المساحة',
#        'سعر المتر', 'السعر الإجمالي'],
#       dtype='object')

# %% [markdown]
# ### Data Quality Checks
# Data quality checks involve the process of ensuring that the data is accurate, complete, consistent, relevant, and reliable.
#
#
# **Here are typical steps involved in checking data quality:**

# %% [markdown]
# #### 1. Reliability:
# Evaluate the data's source and collection process to determine its trustworthiness.

# %% [markdown]
# #### 2. Timeliness:
# Ensure the data is up-to-date and reflective of the current situation or the period of interest for the analysis.

# %% [markdown]
# #### 3. Consistency:
#
# Confirm that the data is consistent within the dataset and across multiple data sources. For example, the same data point should not have different values in different places.

# %% [markdown]
# #### 4. Relevance:
# Assess whether the data is appropriate and applicable for the intended analysis. Data that is not relevant can skew results and lead to incorrect conclusions.
#
# **Key considerations for relevance include:**
#
# > 1. Sample Appropriateness: Confirm that your data sample aligns with your analysis objectives. For instance, utilizing data from the Northern region will not yield accurate insights for the Western region of the Kingdom.
# >
# > 2. Variable Selection: Any column will not be relevant for our analysis, we can get rid of these using the drop() method. We will set the “axis” argument to 1 since we’re dealing with columns, and set the “inplace” argument to True to make the change permanent.

# %% [markdown]
# #### 5. Uniqueness:
# Check for and remove duplicate records to prevent skewed analysis results.

# %%
df[df.duplicated()]
# Out:
#      نوع العقار        الغرض              المدينة          الحي     الواجهة  \
# 13          أرض  تجاري وسكني              الرياض    حي اليرموك       جنوبية
# 19          أرض  تجاري وسكني              الرياض    حي اليرموك       جنوبية
# 34          أرض         سكني   امارة منطقة الرياض       الرياض       جنوبية
# 44          أرض         سكني              الرياض     حي الخليج       شمالية
# 50          أرض         سكني              الرياض    حي الحمراء       جنوبية
# ...         ...          ...                  ...           ...         ...
# 2063        أرض         سكني               الرياض       الرياض        شرقية
# 2096        أرض         سكني              الرياض     حي الروضة       جنوبية
# 2116        أرض         سكني              الرياض     حي العارض   ثلاث شوارع
# 2125        أرض        تجاري              الرياض    حي المهدية       جنوبية
# 2140        أرض         سكني              حريملاء       الرياض        غربية
#
#       المساحة  سعر المتر  السعر الإجمالي
# 13       1089     3300.0         3593700
# 19       1089     3200.0         3484800
# 34        300     1950.0          585000
# 44        300     2600.0          780000
# 50       1000     6000.0         6000000
# ...       ...        ...             ...
# 2063     2450     2400.0         5880000
# 2096      627     4200.0         2633400
# 2116     5450     4600.0        25070000
# 2125      900     7600.0         6840000
# 2140      750     2000.0         1500000
#
# [259 rows x 8 columns]

# %%
df.drop_duplicates(inplace = True)

# %% [markdown]
# #### 6. Completeness:
# Ensure that no critical data is missing. This might mean checking for null values or required fields that are empty.
#
# We will start by checking the dataset for missing or null values. For this, we can use the isna() method which returns a dataframe of boolean values indicating if a field is null or not. To group all missing values by column, we can include the sum() method.

# %%
df.isnull().sum()
# Out:
# نوع العقار         0
# الغرض             47
# المدينة            0
# الحي               0
# الواجهة            0
# المساحة            0
# سعر المتر          0
# السعر الإجمالي     0
# dtype: int64

# %%
count_result = (df == ' ').sum()
count_result
# Out:
# نوع العقار         0
# الغرض              0
# المدينة            3
# الحي              12
# الواجهة            0
# المساحة            0
# سعر المتر          0
# السعر الإجمالي     0
# dtype: int64

# %%
df.dtypes
# Out:
# نوع العقار         object
# الغرض              object
# المدينة            object
# الحي               object
# الواجهة            object
# المساحة             int64
# سعر المتر         float64
# السعر الإجمالي      int64
# dtype: object

# %% [markdown]
# #### 7. Check Accuracy:
#
# Verify that the data is correct and precise. This could involve comparing data samples with known sources or using validation rules.
#
# **The process includes:**
# 1. Validating the appropriateness of data types for the dataset.
# 2. Identifying outliers  using established validation  rule

# %% [markdown]
# ## 2. Data Cleaning:
#
# Preliminary findings from data profiling can lead to cleaning the data by:
# - Handling missing values
# - Correcting errors.
# - Dealing with outliers.

# %% [markdown]
# ## Outlier

# %%
advert_report = sv.analyze(df)
advert_report.show_html('Advertising.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1571 (\N{ARABIC LETTER ALEF WITH HAMZA ABOVE}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Matplotlib currently does not support Arabic natively.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1585 (\N{ARABIC LETTER REH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1590 (\N{ARABIC LETTER DAD}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1571 (\N{ARABIC LETTER ALEF WITH HAMZA ABOVE}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Matplotlib currently does not support Arabic natively.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1585 (\N{ARABIC LETTER REH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1590 (\N{ARABIC LETTER DAD}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1594 (\N{ARABIC LETTER GHAIN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Matplotlib currently does not support Arabic natively.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1610 (\N{ARABIC LETTER YEH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1585 (\N{ARABIC LETTER REH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1605 (\N{ARABIC LETTER MEEM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1593 (\N{ARABIC LETTER AIN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1608 (\N{ARABIC LETTER WAW}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1601 (\N{ARABIC LETTER FEH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1578 (\N{ARABIC LETTER TEH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1580 (\N{ARABIC LETTER JEEM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1575 (\N{ARABIC LETTER ALEF}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1587 (\N{ARABIC LETTER SEEN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1603 (\N{ARABIC LETTER KAF}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1606 (\N{ARABIC LETTER NOON}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1594 (\N{ARABIC LETTER GHAIN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Matplotlib currently does not support Arabic natively.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1610 (\N{ARABIC LETTER YEH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1585 (\N{ARABIC LETTER REH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1605 (\N{ARABIC LETTER MEEM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1593 (\N{ARABIC LETTER AIN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1608 (\N{ARABIC LETTER WAW}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1601 (\N{ARABIC LETTER FEH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1578 (\N{ARABIC LETTER TEH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1580 (\N{ARABIC LETTER JEEM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1575 (\N{ARABIC LETTER ALEF}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1587 (\N{ARABIC LETTER SEEN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1603 (\N{ARABIC LETTER KAF}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1606 (\N{ARABIC LETTER NOON}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1575 (\N{ARABIC LETTER ALEF}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Matplotlib currently does not support Arabic natively.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1604 (\N{ARABIC LETTER LAM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1583 (\N{ARABIC LETTER DAL}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1585 (\N{ARABIC LETTER REH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1593 (\N{ARABIC LETTER AIN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1610 (\N{ARABIC LETTER YEH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1577 (\N{ARABIC LETTER TEH MARBUTA}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1581 (\N{ARABIC LETTER HAH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1605 (\N{ARABIC LETTER MEEM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1569 (\N{ARABIC LETTER HAMZA}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1606 (\N{ARABIC LETTER NOON}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1591 (\N{ARABIC LETTER TAH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1602 (\N{ARABIC LETTER QAF}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1590 (\N{ARABIC LETTER DAD}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1575 (\N{ARABIC LETTER ALEF}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Matplotlib currently does not support Arabic natively.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1604 (\N{ARABIC LETTER LAM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1582 (\N{ARABIC LETTER KHAH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1585 (\N{ARABIC LETTER REH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1580 (\N{ARABIC LETTER JEEM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1581 (\N{ARABIC LETTER HAH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1610 (\N{ARABIC LETTER YEH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1593 (\N{ARABIC LETTER AIN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1590 (\N{ARABIC LETTER DAD}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1592 (\N{ARABIC LETTER ZAH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1607 (\N{ARABIC LETTER HEH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1577 (\N{ARABIC LETTER TEH MARBUTA}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1576 (\N{ARABIC LETTER BEH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1606 (\N{ARABIC LETTER NOON}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1605 (\N{ARABIC LETTER MEEM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1602 (\N{ARABIC LETTER QAF}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1608 (\N{ARABIC LETTER WAW}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1591 (\N{ARABIC LETTER TAH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1583 (\N{ARABIC LETTER DAL}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1569 (\N{ARABIC LETTER HAMZA}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1594 (\N{ARABIC LETTER GHAIN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Matplotlib currently does not support Arabic natively.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1585 (\N{ARABIC LETTER REH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1576 (\N{ARABIC LETTER BEH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1610 (\N{ARABIC LETTER YEH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1577 (\N{ARABIC LETTER TEH MARBUTA}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1588 (\N{ARABIC LETTER SHEEN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1602 (\N{ARABIC LETTER QAF}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1580 (\N{ARABIC LETTER JEEM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1606 (\N{ARABIC LETTER NOON}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1608 (\N{ARABIC LETTER WAW}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1605 (\N{ARABIC LETTER MEEM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1575 (\N{ARABIC LETTER ALEF}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1604 (\N{ARABIC LETTER LAM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1571 (\N{ARABIC LETTER ALEF WITH HAMZA ABOVE}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Matplotlib currently does not support Arabic natively.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1585 (\N{ARABIC LETTER REH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1576 (\N{ARABIC LETTER BEH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1593 (\N{ARABIC LETTER AIN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1588 (\N{ARABIC LETTER SHEEN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1608 (\N{ARABIC LETTER WAW}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1575 (\N{ARABIC LETTER ALEF}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1579 (\N{ARABIC LETTER THEH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1604 (\N{ARABIC LETTER LAM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1605 (\N{ARABIC LETTER MEEM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1610 (\N{ARABIC LETTER YEH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1577 (\N{ARABIC LETTER TEH MARBUTA}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1594 (\N{ARABIC LETTER GHAIN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1580 (\N{ARABIC LETTER JEEM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1606 (\N{ARABIC LETTER NOON}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1602 (\N{ARABIC LETTER QAF}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# Report Advertising.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1606 (\N{ARABIC LETTER NOON}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Matplotlib currently does not support Arabic natively.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1608 (\N{ARABIC LETTER WAW}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1593 (\N{ARABIC LETTER AIN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1575 (\N{ARABIC LETTER ALEF}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1604 (\N{ARABIC LETTER LAM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1602 (\N{ARABIC LETTER QAF}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1585 (\N{ARABIC LETTER REH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1594 (\N{ARABIC LETTER GHAIN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1590 (\N{ARABIC LETTER DAD}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1605 (\N{ARABIC LETTER MEEM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1583 (\N{ARABIC LETTER DAL}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1610 (\N{ARABIC LETTER YEH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1577 (\N{ARABIC LETTER TEH MARBUTA}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1580 (\N{ARABIC LETTER JEEM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1607 (\N{ARABIC LETTER HEH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1587 (\N{ARABIC LETTER SEEN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1581 (\N{ARABIC LETTER HAH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1578 (\N{ARABIC LETTER TEH}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# C:\Users\gharb\anaconda3\Lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 1573 (\N{ARABIC LETTER ALEF WITH HAMZA BELOW}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)

# %%
plt.boxplot(df['المساحة'])
plt.xlabel('price')
plt.ylabel('Frequency')
plt.title(f'Box plot')
plt.show()

# %%
# df = df[df['المساحة'] <= 100000]
# df = df[df['المساحة'] <= 20000]
# df = df[df['المساحة'] <= 10000]
# df = df[df['المساحة'] <= 6000]
df = df[df['المساحة'] <= 2000]

# %%
plt.boxplot(df['سعر المتر'])
plt.xlabel('price')
plt.ylabel('Frequency')
plt.title(f'Box plot')
plt.show()

# %%
# df = df[df['سعر المتر'] <= 30000]
df = df[df['سعر المتر'] <= 7600]

# %%
plt.boxplot(df['السعر الإجمالي'])
plt.xlabel('price')
plt.ylabel('Frequency')
plt.title(f'Box plot')
plt.show()

# %%
df = df[(df['السعر الإجمالي'] <= 6000000) & (df['السعر الإجمالي'] > 93600)]

# %% [markdown]
# ### Correcting errors
#
# -------------------

# %%
df['المدينة'] = df['المدينة'].str.replace(" ", '')
df['الحي'] = df['الحي'].str.replace(" ", '')

# %%
df.fillna('غير معروف',inplace = True)

# %%
df
# Out:
#      نوع العقار        الغرض           المدينة               الحي  \
# 0           أرض    غير معروف  امارةمنطقةالرياض             الرياض
# 1           أرض    غير معروف            الرياض           حيغرناطة
# 4           أرض         سكني            الرياض     حيالنسيمالغربي
# 6           أرض  تجاري وسكني            الرياض           حيالرمال
# 7           أرض  تجاري وسكني            الرياض        حيالملكفيصل
# ...         ...          ...               ...                ...
# 2149        أرض  تجاري وسكني            الرياض           حيالدفاع
# 2151        أرض         سكني            الرياض  حيالعريجاءالغربية
# 2152        أرض  تجاري وسكني            الرياض          حيظهرةلبن
# 2153        أرض  تجاري وسكني            الرياض   حيالعريجاءالغربي
# 2154        أرض         سكني            الرياض   حيالعريجاءالغربي
#
#            الواجهة  المساحة  سعر المتر  السعر الإجمالي
# 0            غربية      375     2900.0         1087500
# 1           شمالية      800     4800.0         3840000
# 4            غربية      750     3200.0         2400000
# 6           شمالية      900     3300.0         2970000
# 7            شرقية      750     3350.0         2512500
# ...            ...      ...        ...             ...
# 2149        شمالية     1173      511.0          599403
# 2151        جنوبية      400     1500.0          600000
# 2152  جنوبية غربية     1050     2380.0         2499000
# 2153         غربية      313     2000.0          626000
# 2154        جنوبية      472     1695.0          800040
#
# [1591 rows x 8 columns]

# %% [markdown]
# ## 3,4. Univariate and Bivariate/Multivariate Analysis

# %%
plt.figure(figsize=(12, 8))
plt.scatter(x='السعر الإجمالي', y='سعر المتر' , data = df)

plt.xlabel('Total Price')
plt.ylabel('Meter Price')
plt.title('Total Price vs Meter Price')

plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.hist(df['السعر الإجمالي'].sort_values(ascending=True).head(100),
         bins=40)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('The Most Expensive Area')
plt.show()
